# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib import rc
from matplotlib.ticker import FuncFormatter

#******************************************************

rc('font',**{'family':'serif','serif':['Times']})
## for Palatino and other serif fonts use:
#rc('font',**{'family':'serif','serif':['Palatino']})
rc('text', usetex=True)

#LaTeX
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#*******************************************************
# %matplotlib notebook
#%matplotlib inline

# %%
# Fill the next list with desired chains to annalize -------------------

chain_root=[#'../chains/nrk_11-28_cluster1_f1.5/nrk_11-28_cluster1_f1.5'
            #,'../chains/nrk_11-26_cluster2_f0.8/nrk_11-26_cluster2_f0.8'
            #,'../chains/nrk_11-26_cluster1_f1.5/nrk_11-26_cluster1_f1.5'
            #,'../chains/nrk_11-14_local3_f1.5/nrk_11-14_local3_f1.5'
            #,'../chains/nrk_11-28_cluster2_f1.7/nrk_11-28_cluster2_f1.7'
            #,'../chains/nrk_11-28_cluster1_f1.5/nrk_11-28_cluster1_f1.5'
            #,'../chains/lcdm/lcdm_12-3_local2/lcdm_12-3_local2'
            '../chains/N2_nakawe/bao+jla/nkw_11-28_cluster1_f1.5/nkw_11-28_cluster1_f1.5'
            ,'../chains/N2_nakawe/bao+jla/nkw_11-28_cluster2_f1.7/nkw_11-28_cluster2_f1.7'
]

# %%
how_many_chains=len(chain_root)
#for i in chain_root:
#    print i

R1=[]


for i in chain_root:
    
    #these lines read .h_info (for R-1 values) and .v_info (for names of parameters) 
    r1=np.genfromtxt(i+'.h_info', skip_header=1, delimiter=':',dtype=None)
    nam=np.genfromtxt(i+'.v_info', skip_header=1, delimiter=':',dtype=None)
    
    #these lines convert the string 'r1'...
    v=r1[0,1].tostring()                       #array with just R-1numbers.(numbers as strings)
    f=v.split('\t')                            #float list with R-1 numbers as floats
    f.pop()                                    #removes last element of list (because it appears "empty")
    
    #these line converts 'nam' into a list of names
    names=nam[:,0]
    
    #print f
    #print names
    
    R1.append(f)

#print(R1)


R1[0]
test=R1[0]
test2=R1[1]
#test3=R1[2]
#test4=R1[3]
#test5=R1[4]

# %%
ind = np.arange(len(test))    # the x locations for the groups, where len(test) is the no. of parameters
width = 0.45                   # the width of the bars

fig, ax = plt.subplots(figsize=(9,7))

plot_ch1 = ax.bar(ind, test, width)
plot_ch2 = ax.bar(ind + width, test2, width)
#plot_ch2 = ax.bar(ind + 2*width, test3, width)
#plot_ch4 = ax.bar(ind + 3*width, test4, width)
#plot_ch4 = ax.bar(ind + 4*width, test5, width)


#ax.bar(x,test)
#ax.bar(x,test2)

#ax.plot(names,test,'o')
#ax.plot(names,test2,'o')


#--------------------------------------------------------------------------------------
ax.legend(loc='best', fancybox=True, framealpha=1)
ax.set_xlabel(r'Parameters',fontsize=15)
ax.set_ylabel(r'R-1 convergence criterium',fontsize=15)
#ax.set_ylim(0,0.5)
ax.grid(which='both',ls=":", c='black',alpha=0.4)
ax.set_title(r'title')
ax.axhline(y=0.01, xmin=0, xmax=1, color='k', linewidth=0.8)
ax.axhline(y=0.05, xmin=0, xmax=1, color='k', linewidth=0.8)
ax.set_xticks(ind + width / 2)
ax.set_xticklabels((r'$\omega_b$', r'$\omega_{cdm}$', r'$b_0$', r'$b_1$', r'$b_2$',
                    r'$\Omega_{\Lambda}$',r'$H_0$'))


#plt.savefig("closure_relation.pdf")
# Out:
# <img src="data:image/png;base64,..." width="900">
# ...
