# %%
#%matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

#******************************************************

rc('font',**{'family':'serif','serif':['Times']})
## for Palatino and other serif fonts use:
#rc('font',**{'family':'serif','serif':['Palatino']})
rc('text', usetex=True)

#LaTeX
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#*******************************************************
# %matplotlib notebook

# %%
chain1=np.loadtxt('../chains/N1_nierika/nrk_11-9_f2.4/2018-11-09_250000__1.txt')
chain2=np.loadtxt('../chains/N1_nierika/nrk_11-9_f2.4/2018-11-09_250000__2.txt')
chain3=np.loadtxt('../chains/N1_nierika/nrk_11-9_f2.4/2018-11-09_250000__3.txt')
chain4=np.loadtxt('../chains/N1_nierika/nrk_11-9_f2.4/2018-11-09_250000__4.txt')
chain5=np.loadtxt('../chains/N1_nierika/nrk_11-9_f2.4/2018-11-09_250000__5.txt')
chain6=np.loadtxt('../chains/N1_nierika/nrk_11-9_f2.4/2018-11-09_250000__6.txt')
chain7=np.loadtxt('../chains/N1_nierika/nrk_11-9_f2.4/2018-11-09_250000__7.txt')
chain8=np.loadtxt('../chains/N1_nierika/nrk_11-9_f2.4/2018-11-09_250000__8.txt')

# %%
fig, ax = plt.subplots(figsize=(9,7))
H = ax.hist((chain1[:,2],chain2[:,2],chain3[:,2],chain4[:,2],chain5[:,2],chain6[:,2],chain7[:,2],chain8[:,2]),
            bins=80,histtype='bar',fill=True, stacked=True)
#--------------------------------------------------------------------------------------
ax.legend(loc='best', fancybox=True, framealpha=1)
ax.set_xlabel(r'value of $H_0$',fontsize=15)
ax.set_ylabel(r'$\#$ of times repeated',fontsize=15)
#ax.set_ylim(bottom=10**-5)
#ax.set_xlim(left=60,right=100)
ax.grid(which='major',ls=":", c='black',alpha=0.4)
ax.set_title(r'Ten-parameter exploration MCMC, JLA+BAO',fontsize=16);
# Out:
# <img src="data:image/png;base64,..." width="900">
# /home/claudio/software/anaconda3/envs/class2-7/lib/python2.7/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
listaparam1=[]

#---------------------------------
for i in chain1[:,2]:
    listaparam1.append(i)
    
for i in chain2[:,2]:
    listaparam1.append(i)

for i in chain3[:,2]:
    listaparam1.append(i)

for i in chain4[:,2]:
    listaparam1.append(i)

for i in chain5[:,2]:
    listaparam1.append(i)

for i in chain6[:,2]:
    listaparam1.append(i)

for i in chain7[:,2]:
    listaparam1.append(i)

for i in chain8[:,2]:
    listaparam1.append(i)
    
print np.mean(listaparam1)
numaceptados=len(listaparam1)
print numaceptados
print max(listaparam1)
# Out:
# 68.3334237404
# 940433
# 84.99899

# %%
fig, ax = plt.subplots(figsize=(9,7))
H = ax.hist((listaparam1),
            bins=80,histtype='bar',fill=True, stacked=True)
#--------------------------------------------------------------------------------------
ax.legend(loc='best', fancybox=True, framealpha=1)
ax.set_xlabel(r'value of $H_0$',fontsize=15)
ax.set_ylabel(r'$\#$ of times repeated',fontsize=15)
#ax.set_ylim(bottom=10**-5)
#ax.set_xlim(left=2*10**-5,right=1)
ax.grid(which='major',ls=":", c='black',alpha=0.4)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
listafreq=[]

#---------------------------------
for i in chain1[:,0]:
    listafreq.append(i)
    
for i in chain2[:,0]:
    listafreq.append(i)

for i in chain3[:,0]:
    listafreq.append(i)

for i in chain4[:,0]:
    listafreq.append(i)

for i in chain5[:,0]:
    listafreq.append(i)

for i in chain6[:,0]:
    listafreq.append(i)

for i in chain7[:,0]:
    listafreq.append(i)

for i in chain8[:,0]:
    listafreq.append(i)
    
print len(listafreq)
print max(listafreq)

numtotcadenas=np.sum(listafreq)
print numtotcadenas
# Out:
# 213754
# 176.0
# 1280000.0

# %%
fig, ax = plt.subplots(figsize=(9,7))
H = ax.hist((chain1[:,7],chain2[:,7],chain3[:,7],chain4[:,7],chain5[:,7],chain6[:,7],chain7[:,7],chain8[:,7]),
            bins=80,histtype='bar',fill=True, stacked=True)
#--------------------------------------------------------------------------------------
ax.legend(loc='best', fancybox=True, framealpha=1)
ax.set_xlabel(r'value of $b_0$',fontsize=15)
ax.set_ylabel(r'$\#$ of times repeated',fontsize=15)
#ax.set_ylim(bottom=10**-5)
#ax.set_xlim(left=2*10**-5,right=1)
ax.grid(which='major',ls=":", c='black',alpha=0.4)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
fig, ax = plt.subplots(figsize=(9,7))
H = ax.hist((chain1[:,8],chain2[:,8],chain3[:,8],chain4[:,8],chain5[:,8],chain6[:,8],chain7[:,8],chain8[:,8]),
            bins=80,histtype='bar',fill=True, stacked=True)
#--------------------------------------------------------------------------------------
ax.legend(loc='best', fancybox=True, framealpha=1)
ax.set_xlabel(r'value of $b_1$',fontsize=15)
ax.set_ylabel(r'$\#$ of times repeated',fontsize=15)
#ax.set_ylim(bottom=10**-5)
#ax.set_xlim(left=2*10**-5,right=1)
ax.grid(which='major',ls=":", c='black',alpha=1)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
fig, ax = plt.subplots(figsize=(9,7))
H = ax.hist((chain1[:,9],chain2[:,9],chain3[:,9],chain4[:,9],chain5[:,9],chain6[:,9],chain7[:,9],chain8[:,9]),
            bins=80,histtype='bar',fill=True, stacked=True)
#--------------------------------------------------------------------------------------
ax.legend(loc='best', fancybox=True, framealpha=1)
ax.set_xlabel(r'value of $\Omega_{DE}$',fontsize=15)
ax.set_ylabel(r'$\#$ of times repeated',fontsize=15)
#ax.set_ylim(bottom=10**-5)
#ax.set_xlim(left=2*10**-5,right=1)
ax.grid(which='major',ls=":", c='black',alpha=1)
# Out:
# <img src="data:image/png;base64,..." width="900">
